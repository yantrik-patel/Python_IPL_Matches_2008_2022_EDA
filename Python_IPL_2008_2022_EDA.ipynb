# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#read CSV file
data=pd.read_csv(r"E:/Projects/IPL_2008_2022/IPL_Matches_2008_2022.csv")

# %%
#let's understand dataframe first
data.shape
# Out:
# (950, 20)

# %%
data.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
#checking null values in all columns
data.isna().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
data[data.Margin.isnull()].head()
# Out:
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
#
#                            Team1                Team2  \
# 114               Delhi Capitals  Sunrisers Hyderabad
# 158        Kolkata Knight Riders  Sunrisers Hyderabad
# 159               Mumbai Indians      Kings XI Punjab
# 184  Royal Challengers Bangalore       Mumbai Indians
# 192               Delhi Capitals      Kings XI Punjab
#
#                                         Venue           TossWinner  \
# 114  MA Chidambaram Stadium, Chepauk, Chennai       Delhi Capitals
# 158                      Sheikh Zayed Stadium  Sunrisers Hyderabad
# 159       Dubai International Cricket Stadium       Mumbai Indians
# ...

# %% [markdown]
# #### This shows that when Margin is null, match results decided by superover. After checking Nan values in other columns, it seems they won't skew our analysis.

# %%
data["WonBy"].value_counts()

# Matches with no results are the ones called off due to variuos reasons like rain etc.
# Out:
# Wickets      509
# Runs         423
# SuperOver     14
# NoResults      4
# Name: WonBy, dtype: int64

# %%
#checking unique values in all columns

data.nunique(axis=0)
# Out:
# ID                 950
# City                33
# Date               706
# Season              15
# MatchNumber         80
# Team1               18
# Team2               18
# Venue               49
# TossWinner          18
# TossDecision         2
# SuperOver            2
# WinningTeam         18
# WonBy                4
# Margin              94
# method               1
# Player_of_Match    262
# Team1Players       932
# Team2Players       937
# Umpire1             58
# Umpire2             60
# dtype: int64

# %%
plt.figure(figsize=(17,4))
plot1=sns.barplot(x=list(data["Season"].value_counts().keys()),y=list(data["Season"].value_counts()),data=data,palette="YlOrBr_r")
plt.xticks(rotation=45)

plt.xlabel("Year")
plt.ylabel("Total Matches")
plt.title("Total matches played each year",fontsize=15,loc='Center',fontweight='bold')

plt.show(plot1)

# %%
data['WinningTeam'].value_counts()
# Out:
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Pune Warriors                   12
# Gujarat Titans                  12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: WinningTeam, dtype: int64

# %%
#merging "Rising Pune Supergiant" and "Rising Pune Supergiants" data
data = data.replace(['Rising Pune Supergiant'], 'Rising Pune Supergiants')

# %%
data['WinningTeam'].value_counts()
# Out:
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Rising Pune Supergiants         15
# Punjab Kings                    13
# Gujarat Lions                   13
# Pune Warriors                   12
# Gujarat Titans                  12
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Name: WinningTeam, dtype: int64

# %% [markdown]
# Analysis: These numbers shows 'Mumbai Indians' have won maximum number of matches.

# %%
plt.figure(figsize=(17,5))
plot2=sns.barplot(x=list(data['WinningTeam'].value_counts().keys()),y=list(data['WinningTeam'].value_counts()),data=data)
plt.xticks(rotation=90)

for bar in plot2.patches:
    plot2.annotate(format(bar.get_height(), '.0f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()),
                  ha='center', va='center',size=15, xytext=(0, 8),textcoords='offset points')

for s in ['top', 'left', 'right']:
    plot2.spines[s].set_visible(False)

plot2.yaxis.set_visible(False)

plt.title("Total Matches Won",fontsize=20,loc='center',fontweight='bold')



plt.show(plot2)

# %% [markdown]
# Analysis: We can see 'Mumbai Indians' and 'Chennai Superkings' are the most successful franchise in IPL history.

# %%
data['Player_of_Match'].value_counts()[0:10]
# Out:
# AB de Villiers    25
# CH Gayle          22
# DA Warner         18
# RG Sharma         18
# MS Dhoni          17
# YK Pathan         16
# SR Watson         16
# KA Pollard        14
# SK Raina          14
# V Kohli           14
# Name: Player_of_Match, dtype: int64

# %%
plt.figure(figsize=(17,5))
plot3=sns.barplot(x=list(data['Player_of_Match'].value_counts()[0:10].keys()),y=list(data['Player_of_Match'].value_counts()[0:10]),data=data)
plt.xticks(rotation=45)

for bar in plot3.patches:
    plot2.annotate(format(bar.get_height(), '.0f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()),
                  ha='center', va='center',size=8, xytext=(0, 8),textcoords='offset points')

for s in ['top', 'left', 'right']:
    plot3.spines[s].set_visible(False)

    
plt.tick_params(left = False, labelleft = False)
plot3.yaxis.set_visible(False)

plt.title("Top 10 'Player of the Match' award winners",fontsize=20,loc='center',fontweight='bold')

plt.show(plot3)

# %% [markdown]
# Analysis: AB Devilliers has won maximum number of Man of the Match awards

# %%
plt.figure(figsize=(17,5))
plot4=sns.barplot(x=list(data['TossWinner'].value_counts().keys()),y=list(data['TossWinner'].value_counts()),data=data)
plt.xticks(rotation=90)

for bar in plot4.patches:
    plot4.annotate(format(bar.get_height(),'.0f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()),
                  ha='center', va='center',size=8, xytext=(0, 8),textcoords='offset points')

for s in ['top', 'left', 'right']:
    plot4.spines[s].set_visible(False)

    
plt.tick_params(left = False, labelleft = False)
plot4.yaxis.set_visible(False)

plt.title("Toss winner Teams",fontsize=20,loc='center',fontweight='bold')

plt.show(plot4)

# %% [markdown]
# Analysis: 'Mumbai Indians' have won most numbers of Tosses, looks like their captain have good luck most of the time :)

# %%
data['WonBy'].value_counts()
# Out:
# Wickets      509
# Runs         423
# SuperOver     14
# NoResults      4
# Name: WonBy, dtype: int64

# %% [markdown]
# ## Batting First Analysis
#
# To avoid confusion for person not familiar with Cricket,
#
# We have column named "WonBy" and have two variables in it. 'Runs'&'Wickets'. When WonBy is Runs, team batting first wins.
# We will see Batting Second teams analysis later.

# %%
batting_first=data[data['WonBy']=='Runs']

# %%
batting_first.head()
# Out:
#          ID         City        Date Season MatchNumber  \
# 2   1312198      Kolkata  2022-05-25   2022  Eliminator
# 8   1304112  Navi Mumbai  2022-05-18   2022          66
# 9   1304111       Mumbai  2022-05-17   2022          65
# 10  1304110  Navi Mumbai  2022-05-16   2022          64
# 11  1304109       Mumbai  2022-05-15   2022          63
#
#                           Team1                  Team2  \
# 2   Royal Challengers Bangalore   Lucknow Super Giants
# 8          Lucknow Super Giants  Kolkata Knight Riders
# 9           Sunrisers Hyderabad         Mumbai Indians
# 10               Delhi Capitals           Punjab Kings
# 11             Rajasthan Royals   Lucknow Super Giants
#
#                                  Venue            TossWinner TossDecision  \
# 2                Eden Gardens, Kolkata  Lucknow Super Giants        field
# 8   Dr DY Patil Sports Academy, Mumbai  Lucknow Super Giants          bat
# ...

# %%
sns.displot(batting_first['Margin'],kde=False,bins=15)
plt.title('Runs Margin Distribution')

plt.show()

# %% [markdown]
# Analysis: Teams who bat first wins by 10 to 20 runs margin most of the time. This distribution also shows the teams are very competitive as most of the matches are won by just 1 to 20 runs margin.

# %%
plt.figure(figsize=(17,5))
plot6=sns.barplot(x=list(batting_first['WinningTeam'].value_counts().keys()),y=list(batting_first['WinningTeam'].value_counts())
                  ,data=batting_first)
plt.xticks(rotation=90)

for bar in plot6.patches:
    plot6.annotate(format(bar.get_height(), '.0f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()),
                  ha='center', va='center',size=15, xytext=(0, 8),textcoords='offset points')

for s in ['top', 'left', 'right']:
    plot6.spines[s].set_visible(False)

plot6.yaxis.set_visible(False)

plt.title("Total Matches Won while Batting first",fontsize=20,loc='center',fontweight='bold')



plt.show(plot6)

# %%
batting_first['WinningTeam'].value_counts()
# Out:
# Mumbai Indians                 66
# Chennai Super Kings            61
# Royal Challengers Bangalore    48
# Kolkata Knight Riders          45
# Kings XI Punjab                40
# Rajasthan Royals               37
# Sunrisers Hyderabad            36
# Delhi Daredevils               25
# Deccan Chargers                18
# Delhi Capitals                 13
# Punjab Kings                    7
# Lucknow Super Giants            7
# Rising Pune Supergiants         7
# Pune Warriors                   6
# Gujarat Titans                  4
# Kochi Tuskers Kerala            2
# Gujarat Lions                   1
# Name: WinningTeam, dtype: int64

# %%
plt.figure(figsize=(7,7))
plot7=plt.pie(list(batting_first['WinningTeam'].value_counts()),labels=list(batting_first['WinningTeam'].value_counts().keys()),
             autopct='%0.1f%%')

plt.title("Batting first Win%",fontsize=20,loc='center',fontweight='bold')
plt.show(plot7)

# %% [markdown]
# Analysis: As per above analysis, 'Mumbai Indians' won most of their matches by batting first.

# %%
plt.figure(figsize=(17,5))
plot8=sns.barplot(x=list(batting_first['Player_of_Match'].value_counts()[0:10].keys()),
                  y=list(batting_first['Player_of_Match'].value_counts()[0:10]),data=data)
plt.xticks(rotation=45)

for bar in plot8.patches:
    plot8.annotate(format(bar.get_height(), '.0f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()),
                  ha='center', va='center',size=8, xytext=(0, 8),textcoords='offset points')

for s in ['top', 'left', 'right']:
    plot8.spines[s].set_visible(False)

    
plt.tick_params(left = False, labelleft = False)
plot8.yaxis.set_visible(False)

plt.title("Batting First Top 10 'Player of the Match' award winners",fontsize=20,loc='left',fontweight='bold')

plot8.text(9, -5, "*These players contribute well while batting first, they are good target setters.", ha='right')

plt.show(plot8)

# %% [markdown]
# ## Batting Second Analysis
#
# When WonBy is Wickets, team batting second wins.

# %%
batting_second=data[data['WonBy']=='Wickets']

# %%
batting_second.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
# 5  1304115     Mumbai  2022-05-21   2022           69
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
# 3             Rajasthan Royals    Gujarat Titans
# 4          Sunrisers Hyderabad      Punjab Kings
# 5               Delhi Capitals    Mumbai Indians
#
#                               Venue           TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad     Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad     Rajasthan Royals        field
# 3             Eden Gardens, Kolkata       Gujarat Titans        field
# ...

# %%
sns.displot(batting_second['Margin'],kde=False,bins=10)
plt.title("Wickets Margin Distribution")

plt.show()

# %% [markdown]
# Analysis: Above histogram shows Wicket margin by which Batting Second teams won the match. Most of the time wicket margin is
# 5 to 7 wickets.

# %%
plt.figure(figsize=(17,5))
plot10=sns.barplot(x=list(batting_second['WinningTeam'].value_counts().keys()),y=list(batting_second['WinningTeam'].value_counts()),data=batting_first)
plt.xticks(rotation=90)

for bar in plot10.patches:
    plot10.annotate(format(bar.get_height(), '.0f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()),
                  ha='center', va='center',size=15, xytext=(0, 8),textcoords='offset points')

for s in ['top', 'left', 'right']:
    plot10.spines[s].set_visible(False)

plot10.yaxis.set_visible(False)

plt.title("Total matches won while Batting Second",fontsize=20,loc='Center',fontweight='bold')



plt.show(plot10)

# %%
plt.figure(figsize=(7,7))
plot11=plt.pie(list(batting_second['WinningTeam'].value_counts()),labels=list(batting_second['WinningTeam'].value_counts().keys()),
             autopct='%0.1f%%')

plt.title("Batting second Win%",fontsize=20,loc='Center',fontweight='bold')
plt.show(plot11)

# %% [markdown]
# Analysis: As per above analysis, 'Kolkata Knight Riders' won most of their matches by batting second.

# %%
plt.figure(figsize=(17,5))
plot12=sns.barplot(x=list(batting_second['Player_of_Match'].value_counts()[0:10].keys()),y=list(batting_second['Player_of_Match'].value_counts()[0:10]),data=data)
plt.xticks(rotation=45)

for bar in plot10.patches:
    plot12.annotate(format(bar.get_height(), '.0f'),(bar.get_x() + bar.get_width() / 2,bar.get_height()),
                  ha='center', va='center',size=8, xytext=(0, 8),textcoords='offset points')

for s in ['top', 'left', 'right']:
    plot12.spines[s].set_visible(False)

    
plt.tick_params(left = False, labelleft = False)
plot12.yaxis.set_visible(False)

plt.title("Batting Second Top 10 'Player of the Match' award winners",fontsize=20,loc='left',fontweight='bold')

plot12.text(9, -5, "*These players contribute well while batting second, they are good chasers.", ha='right')
plt.show(plot12)
